# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data_dir = "data"

# %%
df_akas = pd.read_table('data/title.akas.tsv.gz', compression='gzip', on_bad_lines="skip")
df_basics = pd.read_table('data/title.basics.tsv.gz', compression='gzip', on_bad_lines="skip")
df_crew = pd.read_table('data/title.crew.tsv.gz', compression='gzip', on_bad_lines="skip")
df_ratings = pd.read_table('data/title.ratings.tsv.gz', compression='gzip', on_bad_lines="skip")
# Out:
# /var/folders/27/_w012g5n1c55m7kh9r8jyn488xbh04/T/ipykernel_16104/441841215.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_akas = pd.read_table('data/title.akas.tsv.gz', compression='gzip', on_bad_lines="skip")
# /var/folders/27/_w012g5n1c55m7kh9r8jyn488xbh04/T/ipykernel_16104/441841215.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_basics = pd.read_table('data/title.basics.tsv.gz', compression='gzip', on_bad_lines="skip")

# %%
df_akas.head()
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA       \N
# 1         tt0000001         2                 Carmencita     DE       \N
# 2         tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3         tt0000001         4                 Καρμενσίτα     GR       \N
# 4         tt0000001         5                 Карменсита     RU       \N
# ...             ...       ...                        ...    ...      ...
# 33544408  tt9916852         5             Episódio #3.20     PT       pt
# 33544409  tt9916852         6             Episodio #3.20     IT       it
# 33544410  tt9916852         7               एपिसोड #3.20     IN       hi
# 33544411  tt9916856         1                   The Wind     DE       \N
# 33544412  tt9916856         2                   The Wind     \N       \N
#
#                 types     attributes isOriginalTitle
# ...

# %%
df_akas.language.unique()
# Out:
# array(['\\N', 'ja', 'en', 'sv', 'tr', 'es', 'sr', 'cs', 'fr', 'hi', 'sk',
#        'fa', 'bg', 'ca', 'qbn', 'ru', 'nl', 'pt', 'cmn', 'uz', 'uk',
#        'qbp', 'ar', 'rn', 'bs', 'ga', 'de', 'th', 'yi', 'ka', 'hr', 'sl',
#        'he', 'it', 'tg', 'kk', 'bn', 'da', 'el', 'fi', 'be', 'gsw', 'gl',
#        'eu', 'yue', 'az', 'ms', 'pl', 'id', 'mr', 'qbo', 'mi', 'ta', 'lt',
#        'lv', 'af', 'la', 'hy', 'ur', 'te', 'ml', 'tl', 'mk', 'et', 'gd',
#        'cy', 'qal', 'ro', 'xh', 'gu', 'kn', 'eka', 'ko', 'ky', 'wo', 'no',
#        'is', 'hu', 'sq', 'vi', 'zh', 'tk', 'pa', 'ps', 'zu', 'sd', 'ku',
#        'roa', 'tn', 'rm', 'su', 'jv', 'st', 'prs', 'lb', 'fro', 'haw',
#        'mn', 'lo', 'my', 'am', 'qac', 'ne', 'myv', 'br', 'iu', 'cr'],
#       dtype=object)

# %%
df_akas_small = df_akas[df_akas.language.isin(["en", "de"])]

# %%
df_akas_small.head()
# Out:
#        titleId  ordering                                title region language  \
# 39   tt0000005         4                     Blacksmith Scene     CA       en
# 96   tt0000010         6  La sortie de l'usine Lumière à Lyon     CA       en
# 116  tt0000012        22               The Arrival of a Train    XWW       en
# 118  tt0000012        24     L'arrivée d'un train à La Ciotat     CA       en
# 121  tt0000012        27               The Arrival of a Train    XEU       en
#
#            types attributes isOriginalTitle
# 39   imdbDisplay         \N               0
# 96   imdbDisplay         \N               0
# 116  imdbDisplay         \N               0
# 118  imdbDisplay         \N               0
# 121  imdbDisplay         \N               0

# %%
df_akas_small.shape
# Out:
# (4185887, 8)

# %%
df_basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9308028  tt9916848  tvEpisode              Episode #3.17
# 9308029  tt9916850  tvEpisode              Episode #3.19
# 9308030  tt9916852  tvEpisode              Episode #3.20
# 9308031  tt9916856      short                   The Wind
# 9308032  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# ...

# %%
# ?pd.merge
# Out:
# Signature:
# pd.merge(
#     left: 'DataFrame | Series',
#     right: 'DataFrame | Series',
#     how: 'str' = 'inner',
#     on: 'IndexLabel | None' = None,
#     left_on: 'IndexLabel | None' = None,
#     right_on: 'IndexLabel | None' = None,
#     left_index: 'bool' = False,
#     right_index: 'bool' = False,
#     sort: 'bool' = False,
#     suffixes: 'Suffixes' = ('_x', '_y'),
#     copy: 'bool' = True,
#     indicator: 'bool' = False,
#     validate: 'str | None' = None,
# ) -> 'DataFrame'
# Docstring:
# Merge DataFrame or named Series objects with a database-style join.
#
# A named Series object is treated as a DataFrame with a single named column.
#
# The join is done on columns or indexes. If joining columns on
# columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
# on indexes or indexes on a column or columns, the index will be passed on.
# When performing a cross merge, no column specifications to merge on are
# allowed.
#
# .. warning::
#
# ...

# %%
pd.merge(df_akas_small, df_basics, left_on="titleId", right_on="tconst", how="left")
# Out:
#            titleId  ordering                                title region  \
# 0        tt0000005         4                     Blacksmith Scene     CA
# 1        tt0000010         6  La sortie de l'usine Lumière à Lyon     CA
# 2        tt0000012        22               The Arrival of a Train    XWW
# 3        tt0000012        24     L'arrivée d'un train à La Ciotat     CA
# 4        tt0000012        27               The Arrival of a Train    XEU
# ...            ...       ...                                  ...    ...
# 4185882  tt9916844         2                          Folge #3.15     DE
# 4185883  tt9916846         2                          Folge #3.18     DE
# 4185884  tt9916848         2                          Folge #3.17     DE
# 4185885  tt9916850         7                          Folge #3.19     DE
# 4185886  tt9916852         3                          Folge #3.20     DE
#
#         language        types attributes isOriginalTitle     tconst  \
# ...

# %%
df_akas_small.types.unique()
# Out:
# array(['imdbDisplay', 'alternative', 'festival', '\\N', 'dvd', 'tv',
#        'working', 'video', 'original'], dtype=object)
